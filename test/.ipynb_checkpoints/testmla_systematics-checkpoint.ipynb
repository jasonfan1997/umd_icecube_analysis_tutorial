# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from threeML import *
import numpy as np
from threeML.plugins import *
from skylab.datasets import Datasets
from astropy import units as u
from imp import reload
import scipy.optimize
import mla.core
import mla.injection
import mla.spectral
import warnings
warnings.filterwarnings("ignore")

import os, sys, glob, abc

def read(filelist):
    data = []
    for f in sorted(filelist):
        x = np.load(f)
        if len(data) == 0: data = x.copy()
        else: data = np.concatenate([data, x])
    return data

# Where is the dataset stored?
dataset = "/data/i3store/users/mjlarson/student_data"

# Read in all of the data files
data_files = dataset + "/IC86_*exp.npy"
exp = read(glob.glob(data_files))

# Read in all of the MC files 
sim_files = dataset + "/IC86*MC*npy"
mc = read(glob.glob(sim_files))

# Set the angular error floor to 0.2 degrees
#exp['angErr'][exp['angErr']<np.deg2rad(0.2)] = np.deg2rad(0.2)
#mc['angErr'][mc['angErr']<np.deg2rad(0.2)] = np.deg2rad(0.2)

exp['ra']=np.random.uniform(0,2*np.pi,size=len(exp))
grl = np.load("/data/i3store/users/mjlarson/student_data/GRL/IC86_2012_exp.npy")
livetime = np.sum(grl['livetime'])
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
# /data/disk01/home/jasonfan/threeML/threeML/__init__.py:12: UserWarning: No DISPLAY variable set. Using backend for graphics without display (Agg)
#   warnings.warn("No DISPLAY variable set. Using backend for graphics without display (Agg)")
# /data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/astromodels/core/parameter.py:555: UserWarning: We have set the min_value of K to 1e-99 because there was a postive transform
#   warnings.warn('We have set the min_value of %s to 1e-99 because there was a postive transform' % self.path)
# /data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/astromodels/core/parameter.py:555: UserWarning: We have set the min_value of xc to 1e-99 because there was a postive transform
#   warnings.warn('We have set the min_value of %s to 1e-99 because there was a postive transform' % self.path)
#
# WARNING UserWarning: Using default configuration from /data/disk01/home/jasonfan/threeML/threeML/data/threeML_config.yml. You might want to copy it to /data/disk01/home/jasonfan/.threeML/threeML_config.yml to customize it and avoid this warning.
#
#
# WARNING RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# INFO:keyring.backend:Loading KWallet
# INFO:keyring.backend:Loading SecretService
# INFO:keyring.backend:Loading Windows
# INFO:keyring.backend:Loading chainer
# INFO:keyring.backend:Loading macOS
#
# WARNING RuntimeWarning: Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
#
#
# WARNING RuntimeWarning: Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
#
#
# WARNING RuntimeWarning: Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal performances in 3ML
#
#
# WARNING RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
#
# WARNING RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
#
# WARNING RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
#
# WARNING RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
# testmla=mla.core.LLH_point_source(np.radians(83.63) ,np.radians(22.0145) , exp[:5] , mc, "PowerLaw", background = exp , \
#                               background_time_profile = (56224,56324),fit_position=True
#                                   ,file_name="testprecomputed")

# %%
testmla=mla.core.LLH_point_source(np.radians(83.63) ,np.radians(22.0145) , exp[:5] , mc, "PowerLaw", background = exp , \
                              background_time_profile = (56224,56324),fit_position=False
                                  ,sob_spline="testprecomputed_2dbkg.pkl")

# %%
sp=mla.spectral.PowerLaw(1e3 , 1e-9 , -2)
injector=mla.injection.PSinjector(sp,mc,background_time_profile = (56224,56324))
injector.set_backround(exp,grl,background_window=100)
injector.set_source_location(np.radians(83.63) ,np.radians(22.0145) )

# %%
test=injector.sample_nevents(10000)

# %%
testdata=np.load("testdata.npy")
testdata['time'] = 56225

# %%
len(testdata)
# Out:
# 33967

# %%
testmla.update_data(testdata[testdata['run']>100000000])
#testmla.update_data(testdata)
useless=testmla.eval_llh_fit()
tempresult=testmla.get_fit_result()

# %%
np.save("energymla.npy",testmla.energy)
np.save("temp.npy",testmla.data)

# %%
testmla.update_energy_weight(gamma=-2)

# %%
testmla.energy
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan])

# %%
sob_ratios = testmla.evaluate_interpolated_ratio()
sob_spline = np.zeros(len(self.data), dtype=object)
for i in range(len(testmla.data)):
    spline = scipy.interpolate.UnivariateSpline(testmla.gamma_point,
                                np.log(sob_ratios[:,i]),
                                k = 3,
                                s = 0,
                                ext = 'raise')
    sob_spline[i] = spline
# Out:
# -2.0

# %%
from matplotlib import pyplot as plt, colors
fig, ax = plt.subplots(figsize=(10,6))
sindec=np.linspace(-1,1,100)
logE=np.linspace(1,8,100)
ratio = np.zeros((100,100))
for i in range(100):
    for j in range(100):
        ratio[i][j] = np.exp(testmla.ratio[8]([sindec[i],logE[j]]))
cmesh = ax.pcolormesh(np.linspace(-1,1,100), np.linspace(1,8,100), ratio.T,
                     cmap = 'RdBu',
                     norm = colors.LogNorm(),
                     vmin = 1e2,
                     vmax = 1e-2)
cbar = plt.colorbar(cmesh, ax=ax)
ax.text(-0.95, 1.1, 
        "Signal/Background",
        horizontalalignment='left',
        verticalalignment='bottom',
        fontsize=14)
ax.grid(alpha=0.2)
ax.set_xlabel(r"sin($\delta$)", fontsize=16)
ax.set_ylabel(r"log$_{10}$(E)", fontsize=16)
ax.tick_params(which='both', labelsize=14)
ax.set_title(r"gamma = 2,mla ,regular grid interpolator", fontsize=16)
cbar.ax.set_ylabel("Signal/Background", fontsize=16)
cbar.ax.tick_params(labelsize=14)
np.save("mla_ratio.npy",ratio.T)

# %%
testmla.ratio[10]([0.3,2])
# Out:
# array([-2.66734719])

# %%
in_ns=np.arange(5,101)
def injectns(inject_ns):
    result = []
    ns=inject_ns
    for i in range(100):
        testmla.update_data(injector.draw_data())
        testmla.modify_injection(injector.sample_nevents(ns))
        useless=testmla.eval_llh_fit()
        tempresult=testmla.get_fit_result()
        result.append((inject_ns,tempresult[0],tempresult[1],tempresult[2]))
    return np.array(result)

# %%
from multiprocessing import Pool
p=Pool(30)
allresult=p.map(injectns,in_ns)
allresult=np.array(allresult)
np.save("allresult_new.npy",allresult)
p.close()
# Out:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-41:
# Process ForkPoolWorker-53:
# Process ForkPoolWorker-51:
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-40:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-60:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-47:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-57:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-58:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-46:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-45:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-fe022c3fa621> in <module>
#       3 from multiprocessing import Pool
#       4 p=Pool(30)
# ----> 5 allresult=p.map(injectns,in_ns)
#       6 allresult=np.array(allresult)
#       7 np.save("allresult_new.npy",allresult)
#
# ~/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     286         in a list that is returned.
#     287         '''
# --> 288         return self._map_async(func, iterable, mapstar, chunksize).get()
#     289
#     290     def starmap(self, func, iterable, chunksize=None):
#
# ~/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     662
#     663     def get(self, timeout=None):
# --> 664         self.wait(timeout)
#     665         if not self.ready():
#     666             raise TimeoutError
#
# ~/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     659
#     660     def wait(self, timeout=None):
# --> 661         self._event.wait(timeout)
#     662
#     663     def get(self, timeout=None):
#
# ~/miniconda3/envs/p3/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/miniconda3/envs/p3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-16-0aa410b75029>", line 6, in injectns
#     testmla.update_data(injector.draw_data())
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 346, in update_data
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 439, in update_energy_weight
#     ext = 'raise')
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 176, in __init__
#     if not all(diff(x) > 0.0):
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 423, in _minimize_slsqp
#     g = append(fprime(x), 0.0)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 399, in _minimize_slsqp
#     fx = func(x)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 423, in _minimize_slsqp
#     g = append(fprime(x), 0.0)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 58, in approx_jacobian
#     f0 = atleast_1d(func(*((x0,)+args)))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 63, in approx_jacobian
#     jac[i] = (func(*((x0+dx,)+args)) - f0)/epsilon
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 399, in _minimize_slsqp
#     fx = func(x)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 423, in _minimize_slsqp
#     g = append(fprime(x), 0.0)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 63, in approx_jacobian
#     jac[i] = (func(*((x0+dx,)+args)) - f0)/epsilon
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# KeyboardInterrupt
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 300, in __call__
#     if x.size == 0:
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 582, in splev
#     c[0][0]
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# IndexError: invalid index to scalar variable.
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 582, in splev
#     c[0][0]
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# IndexError: invalid index to scalar variable.
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 423, in _minimize_slsqp
#     g = append(fprime(x), 0.0)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 582, in splev
#     c[0][0]
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#
# During handling of the above exception, another exception occurred:
#
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# IndexError: invalid index to scalar variable.
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#
# During handling of the above exception, another exception occurred:
#
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#
# During handling of the above exception, another exception occurred:
#
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 63, in approx_jacobian
#     jac[i] = (func(*((x0+dx,)+args)) - f0)/epsilon
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
# Traceback (most recent call last):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 423, in _minimize_slsqp
#     g = append(fprime(x), 0.0)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 399, in _minimize_slsqp
#     fx = func(x)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 353, in splev
#     if isinstance(tck, BSpline):
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 58, in approx_jacobian
#     f0 = atleast_1d(func(*((x0,)+args)))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "<ipython-input-16-0aa410b75029>", line 7, in injectns
#     testmla.modify_injection(injector.sample_nevents(ns))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 581, in modify_injection
#     self.add_injection(sample)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 399, in _minimize_slsqp
#     fx = func(x)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
#   File "<ipython-input-16-0aa410b75029>", line 6, in injectns
#     testmla.update_data(injector.draw_data())
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 558, in add_injection
#     self.update_energy_weight()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 456, in update_energy_weight
#     method = 'SLSQP',
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 399, in _minimize_slsqp
#     fx = func(x)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/_minimize.py", line 609, in minimize
#     constraints, callback=callback, **options)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 423, in _minimize_slsqp
#     g = append(fprime(x), 0.0)
# ...
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 63, in approx_jacobian
#     jac[i] = (func(*((x0+dx,)+args)) - f0)/epsilon
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/numpy/core/numeric.py", line 469, in asarray
#     @set_module('numpy')
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 298, in __call__
#     x = np.asarray(x)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 58, in approx_jacobian
#     f0 = atleast_1d(func(*((x0,)+args)))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 607, in splev
#     return y.reshape(shape)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 63, in approx_jacobian
#     jac[i] = (func(*((x0+dx,)+args)) - f0)/epsilon
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/numpy/core/numeric.py", line 538, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 423, in _minimize_slsqp
#     g = append(fprime(x), 0.0)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 423, in _minimize_slsqp
#     g = append(fprime(x), 0.0)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 602, in splev
#     if ier == 1:
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 597, in splev
#     x = atleast_1d(x).ravel()
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/numpy/core/numeric.py", line 469, in asarray
#     @set_module('numpy')
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 597, in splev
#     x = atleast_1d(x).ravel()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 63, in approx_jacobian
#     jac[i] = (func(*((x0+dx,)+args)) - f0)/epsilon
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/numpy/core/shape_base.py", line 73, in atleast_1d
#     if len(res) == 1:
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/slsqp.py", line 63, in approx_jacobian
#     jac[i] = (func(*((x0+dx,)+args)) - f0)/epsilon
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 597, in splev
#     x = atleast_1d(x).ravel()
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/numpy/core/shape_base.py", line 69, in atleast_1d
#     result = ary.reshape(1)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 595, in splev
#     x = asarray(x)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 595, in splev
#     x = asarray(x)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/numpy/core/numeric.py", line 469, in asarray
#     @set_module('numpy')
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 582, in splev
#     c[0][0]
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 595, in splev
#     x = asarray(x)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/numpy/core/numeric.py", line 469, in asarray
#     @set_module('numpy')
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 595, in splev
#     x = asarray(x)
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/numpy/core/numeric.py", line 469, in asarray
#     @set_module('numpy')
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 597, in splev
#     x = atleast_1d(x).ravel()
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 445, in inner_ts
#     e_lh_ratio = self.get_energy_sob(gamma, sob_spline)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 582, in splev
#     c[0][0]
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/numpy/core/shape_base.py", line 67, in atleast_1d
#     ary = asanyarray(ary)
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 582, in splev
#     c[0][0]
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
#   File "/data/disk01/home/jasonfan/umd_icecube_analysis_tutorial/mla/mla/core.py", line 474, in get_energy_sob
#     final_sob_ratios[i] = np.exp(spline(gamma))
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py", line 312, in __call__
#     return fitpack.splev(x, self._eval_args, der=nu, ext=ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 592, in splev
#     if ext not in (0, 1, 2, 3):
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 597, in splev
#     x = atleast_1d(x).ravel()
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/fitpack.py", line 368, in splev
#     return _impl.splev(x, tck, der, ext)
# KeyboardInterrupt
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py", line 582, in splev
#     c[0][0]
#   File "/data/disk01/home/jasonfan/miniconda3/envs/p3/lib/python3.6/site-packages/numpy/core/shape_base.py", line 72, in atleast_1d
#     res.append(result)
# KeyboardInterrupt
# KeyboardInterrupt

# %%
gamma_list=[]
ts_list=[]
ns_list=[]
for i in range(allresult.shape[0]):
    ns_inject=allresult[i][0][0]
    gamma=allresult[i][:,1]
    ts=(-allresult[i][:,3])
    ns=allresult[i][:,2]
    gamma_list.append(np.array([gamma.mean(),gamma.std()]))
    ts_list.append(np.array([ts.mean(),ts.std()]))
    ns_list.append(np.array([ns.mean(),ts.std()]))

    
gamma_list=np.array(gamma_list)
ts_list=np.array(ts_list)
ns_list=np.array(ns_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-068a0d998bf8> in <module>
#       2 ts_list=[]
#       3 ns_list=[]
# ----> 4 for i in range(allresult.shape[0]):
#       5     ns_inject=allresult[i][0][0]
#       6     gamma=allresult[i][:,1]
#
# NameError: name 'allresult' is not defined

# %%
fig, ax = plt.subplots(figsize=(16,12))


ax.errorbar(in_ns, gamma_list[:,0],
            yerr=gamma_list[:,1],
            fmt='-',label="gamma=-2")


ax.hlines(-2,5,100)
ax.set_xlabel("injected ns")
ax.set_ylabel("gamma")
ax.set_title("gamma vs injected ns")
ax.legend()

# %%
sp=mla.spectral.PowerLaw(1e3 , 1e-9 , -2.5)
injector=mla.injection.PSinjector(sp,mc,background_time_profile = (56224,56324))
injector.set_backround(exp,grl,background_window=100)
injector.set_source_location(np.radians(83.63) ,np.radians(22.0145) )
def injectns(inject_ns):
    result = []
    ns=inject_ns
    for i in range(100):
        testmla.update_data(injector.draw_data())
        testmla.modify_injection(injector.sample_nevents(ns))
        useless=testmla.eval_llh_fit()
        tempresult=testmla.get_fit_result()
        result.append((inject_ns,tempresult[0],tempresult[1],tempresult[2]))
    return np.array(result)
p=Pool(30)
allresult25=p.map(injectns,in_ns)
allresult25=np.array(allresult25)
np.save("allresult2.5.npy",allresult25)
p.close()


gamma_list25=[]
ts_list25=[]
ns_list25=[]
for i in range(allresult25.shape[0]):
    ns_inject=allresult25[i][0][0]
    gamma=allresult25[i][:,1]
    ts=(-allresult25[i][:,3])
    ns=allresult25[i][:,2]
    gamma_list25.append(np.array([gamma.mean(),gamma.std()]))
    ts_list25.append(np.array([ts.mean(),ts.std()]))
    ns_list25.append(np.array([ns.mean(),ts.std()]))

    
gamma_list25=np.array(gamma_list25)
ts_list25=np.array(ts_list25)
ns_list25=np.array(ns_list25)


sp=mla.spectral.PowerLaw(1e3 , 1e-9 , -3)
injector=mla.injection.PSinjector(sp,mc,background_time_profile = (56224,56324))
injector.set_backround(exp,grl,background_window=100)
injector.set_source_location(np.radians(83.63) ,np.radians(22.0145) )
def injectns(inject_ns):
    result = []
    ns=inject_ns
    for i in range(100):
        testmla.update_data(injector.draw_data())
        testmla.modify_injection(injector.sample_nevents(ns))
        useless=testmla.eval_llh_fit()
        tempresult=testmla.get_fit_result()
        result.append((inject_ns,tempresult[0],tempresult[1],tempresult[2]))
    return np.array(result)
p=Pool(30)
allresult3=p.map(injectns,in_ns)
allresult3=np.array(allresult3)
np.save("allresult3.npy",allresult3)
p.close()


gamma_list3=[]
ts_list3=[]
ns_list3=[]
for i in range(allresult3.shape[0]):
    ns_inject=allresult3[i][0][0]
    gamma=allresult3[i][:,1]
    ts=(-allresult3[i][:,3])
    ns=allresult3[i][:,2]
    gamma_list3.append(np.array([gamma.mean(),gamma.std()]))
    ts_list3.append(np.array([ts.mean(),ts.std()]))
    ns_list3.append(np.array([ns.mean(),ts.std()]))

    
gamma_list3=np.array(gamma_list3)
ts_list3=np.array(ts_list3)
ns_list3=np.array(ns_list3)

# %%
fig, ax = plt.subplots(figsize=(16,12))


ax.errorbar(in_ns, gamma_list[:,0],
            yerr=gamma_list[:,1],
            fmt='-',label="gamma=-2")


ax.hlines(-2,5,100)
ax.errorbar(in_ns, gamma_list25[:,0],
            yerr=gamma_list25[:,1],
            fmt='-',label="gamma=-2.5")
ax.hlines(-2.5,5,100)
ax.errorbar(in_ns, gamma_list3[:,0],
            yerr=gamma_list3[:,1],
            fmt='-',label="gamma=-3")
ax.hlines(-3,5,100)
ax.set_xlabel("injected ns")
ax.set_ylabel("gamma")
ax.set_title("gamma vs injected ns")
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(16,12))


ax.errorbar(in_ns, ns_list[:,0],
            yerr=ns_list[:,1],
            fmt='-',label="gamma=-2")
ax.errorbar(in_ns, ns_list25[:,0],
            yerr=ns_list25[:,1],
            fmt='-',label="gamma=-2.5")

ax.errorbar(in_ns, ns_list3[:,0],
            yerr=ns_list3[:,1],
            fmt='-',label="gamma=-3")
# ax.errorbar(in_ns, ns_list[:,0],
#             yerr=0,
#             fmt='-',label="gamma=-2")
# ax.errorbar(in_ns, ns_list25[:,0],
#             yerr=0,
#             fmt='-',label="gamma=-2.5")

# ax.errorbar(in_ns, ns_list3[:,0],
#             yerr=0,
#             fmt='-',label="gamma=-3")


x=np.linspace(5,100,1000)
ax.plot(x,x,label="y=x")
ax.set_xlabel("injected ns")
ax.set_ylabel("fitted ns")
ax.set_title("gamma=-2")
ax.legend(fontsize=16)

# %%
fig, ax = plt.subplots(figsize=(16,12))

in_ns = np.linspace(1,40,100)

ax.errorbar(in_ns, ns_list[:,0],
            yerr=0,
            fmt='-',label="gamma=-2")
ax.errorbar(in_ns, ns_list25[:,0],
            yerr=0,
            fmt='-',label="gamma=-2.5")

ax.errorbar(in_ns, ns_list3[:,0],
            yerr=0,
            fmt='-',label="gamma=-3")


x=np.linspace(5,100,1000)
ax.plot(x,x,label="y=x")
ax.set_xlabel("injected ns")
ax.set_ylabel("fitted ns")
ax.set_title("gamma=-2")
ax.legend(fontsize=16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-358b0bfc70d9> in <module>
#       3 in_ns = np.linspace(1,40,100)
#       4
# ----> 5 ax.errorbar(in_ns, ns_list[:,0],
#       6             yerr=0,
#       7             fmt='-',label="gamma=-2")
#
# NameError: name 'ns_list' is not defined
